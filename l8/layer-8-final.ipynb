# %%
# import libraries

import pandas as pd
import numpy as np

from sklearn.svm import SVC
from sklearn.decomposition import PCA
from sklearn.metrics import accuracy_score

# %%
# create a list of feature names

FEATURES = []
for i in range(1, 769):
  FEATURES.append('feature_' + str(i))

# %%
# create a list of label names

LABELS = ['label_1', 'label_2', 'label_3', 'label_4']

# %%
# read the data

df_train = pd.read_csv('../Dataset/layer_8_train.csv')
df_valid = pd.read_csv('../Dataset/layer_8_valid.csv')
df_test = pd.read_csv('../Dataset/layer_8_test.csv')

# %%
# store the data in a dictionary for each label

data_dict = dict()

for label in LABELS:
  data_dict[label] = dict()

  data_dict[label]['x_train'] = df_train[df_train[label].notna()][FEATURES].values
  data_dict[label]['y_train'] = df_train[df_train[label].notna()][label].values
  data_dict[label]['x_valid'] = df_valid[df_valid[label].notna()][FEATURES].values
  data_dict[label]['y_valid'] = df_valid[df_valid[label].notna()][label].values
  data_dict[label]['x_test'] = df_test[FEATURES].values
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /home/akila-i/Documents/Uni/Sem7/Machine Learning/project/cs4622-machine_learning-project/combined-model/layer-8-final.ipynb Cell 5 line 8
#       <a href='vscode-notebook-cell:/home/akila-i/Documents/Uni/Sem7/Machine%20Learning/project/cs4622-machine_learning-project/combined-model/layer-8-final.ipynb#W4sZmlsZQ%3D%3D?line=4'>5</a> for label in LABELS:
#       <a href='vscode-notebook-cell:/home/akila-i/Documents/Uni/Sem7/Machine%20Learning/project/cs4622-machine_learning-project/combined-model/layer-8-final.ipynb#W4sZmlsZQ%3D%3D?line=5'>6</a>   data_dict[label] = dict()
# ----> <a href='vscode-notebook-cell:/home/akila-i/Documents/Uni/Sem7/Machine%20Learning/project/cs4622-machine_learning-project/combined-model/layer-8-final.ipynb#W4sZmlsZQ%3D%3D?line=7'>8</a>   data_dict[label]['x_train'] = df_train[df_train[label].notna()][FEATURES].values
#       <a href='vscode-notebook-cell:/home/akila-i/Documents/Uni/Sem7/Machine%20Learning/project/cs4622-machine_learning-project/combined-model/layer-8-final.ipynb#W4sZmlsZQ%3D%3D?line=8'>9</a>   data_dict[label]['y_train'] = df_train[df_train[label].notna()][label].values
#      <a href='vscode-notebook-cell:/home/akila-i/Documents/Uni/Sem7/Machine%20Learning/project/cs4622-machine_learning-project/combined-model/layer-8-final.ipynb#W4sZmlsZQ%3D%3D?line=9'>10</a>   data_dict[label]['x_valid'] = df_valid[df_valid[label].notna()][FEATURES].values
#
# File ~/.pyenv/versions/3.9.9/envs/ml-py3.9/lib/python3.9/site-packages/pandas/core/frame.py:3752, in DataFrame.__getitem__(self, key)
#    3750 # Do we have a (boolean) 1d indexer?
#    3751 if com.is_bool_indexer(key):
# -> 3752     return self._getitem_bool_array(key)
#    3754 # We are left with two options: a single key, and a collection of keys,
#    3755 # We interpret tuples as collections only for non-MultiIndex
#    3756 is_single_key = isinstance(key, tuple) or not is_list_like(key)
#
# File ~/.pyenv/versions/3.9.9/envs/ml-py3.9/lib/python3.9/site-packages/pandas/core/frame.py:3808, in DataFrame._getitem_bool_array(self, key)
#    3805 key = check_bool_indexer(self.index, key)
#    3807 if key.all():
# -> 3808     return self.copy(deep=None)
#    3810 indexer = key.nonzero()[0]
#    3811 return self._take_with_is_copy(indexer, axis=0)
#
# File ~/.pyenv/versions/3.9.9/envs/ml-py3.9/lib/python3.9/site-packages/pandas/core/generic.py:6452, in NDFrame.copy(self, deep)
#    6342 @final
#    6343 def copy(self: NDFrameT, deep: bool_t | None = True) -> NDFrameT:
#    6344     """
#    6345     Make a copy of this object's indices and data.
#    6346
#    (...)
#    6450     dtype: object
#    6451     """
# -> 6452     data = self._mgr.copy(deep=deep)
#    6453     self._clear_item_cache()
#    6454     return self._constructor(data).__finalize__(self, method="copy")
#
# File ~/.pyenv/versions/3.9.9/envs/ml-py3.9/lib/python3.9/site-packages/pandas/core/internals/managers.py:653, in BaseBlockManager.copy(self, deep)
#     650 else:
#     651     new_axes = list(self.axes)
# --> 653 res = self.apply("copy", deep=deep)
#     654 res.axes = new_axes
#     656 if self.ndim > 1:
#     657     # Avoid needing to re-compute these
#
# File ~/.pyenv/versions/3.9.9/envs/ml-py3.9/lib/python3.9/site-packages/pandas/core/internals/managers.py:352, in BaseBlockManager.apply(self, f, align_keys, **kwargs)
#     350         applied = b.apply(f, **kwargs)
#     351     else:
# --> 352         applied = getattr(b, f)(**kwargs)
#     353     result_blocks = extend_blocks(applied, result_blocks)
#     355 out = type(self).from_blocks(result_blocks, self.axes)
#
# File ~/.pyenv/versions/3.9.9/envs/ml-py3.9/lib/python3.9/site-packages/pandas/core/internals/blocks.py:540, in Block.copy(self, deep)
#     538 refs: BlockValuesRefs | None
#     539 if deep:
# --> 540     values = values.copy()
#     541     refs = None
#     542 else:
#
# KeyboardInterrupt:

# %%
# create svc models for each label

model_dict = dict()

model_dict[LABELS[0]] = SVC(C=100, gamma='scale', kernel='rbf')
model_dict[LABELS[1]] = SVC(C=30, gamma='scale', kernel='rbf')
model_dict[LABELS[2]] = SVC(C=100, gamma='scale', kernel='rbf')
model_dict[LABELS[3]] = SVC(C=30, gamma='scale', kernel='rbf')

# %%
# PCA for label 2, 3, 4

pca = PCA(n_components=0.95, svd_solver='full')

for label in LABELS[1:]:
  data_dict[label]['x_train'] = pca.fit_transform(data_dict[label]['x_train'])
  data_dict[label]['x_valid'] = pca.transform(data_dict[label]['x_valid'])
  data_dict[label]['x_test'] = pca.transform(data_dict[label]['x_test'])

# %%
# train and test the models for each label

df_test_pred = pd.DataFrame()

for label in LABELS:
  model_dict[label].fit(data_dict[label]['x_train'], data_dict[label]['y_train'])
  data_dict[label]['y_pred'] = model_dict[label].predict(data_dict[label]['x_valid'])
  print('accuracy_score for {}: '.format(label), accuracy_score(data_dict[label]['y_valid'], data_dict[label]['y_pred']))

  data_dict[label]['y_pred_test'] = model_dict[label].predict(data_dict[label]['x_test'])
  df_test_pred[label] = data_dict[label]['y_pred_test']
# Out:
# accuracy_score for label_1:  0.9746666666666667
# accuracy_score for label_2:  0.9442934782608695
# accuracy_score for label_3:  0.9986666666666667
# accuracy_score for label_4:  0.984

# %%
# df_test_pred.index += 1
# df_test_pred.index.name = 'ID'
# df_test_pred.to_csv('submission_final.csv')

# %%
# get predictions for train data

# df_train_pred = dict()

for label in LABELS:
  data_dict[label]['y_pred_train'] = model_dict[label].predict(data_dict[label]['x_train'])

  pd.DataFrame(data_dict[label]['y_pred_train']).to_csv('layer_8_train_pred_{}.csv'.format(label), index=False)
  # df_train_pred[label] = data_dict[label]['y_pred_train']


# print(data_dict['label_1']['y_pred_train'])
# save the predictions

# df_train_pred.to_csv('layer_8_train_pred.csv', index=False)

# %%
print(len(data_dict['label_1']['y_pred_train']))
print(len(data_dict['label_2']['y_pred_train']))
print(len(data_dict['label_3']['y_pred_train']))
print(len(data_dict['label_4']['y_pred_train']))
# Out:
# 28520
# 28040
# 28520
# 28520
